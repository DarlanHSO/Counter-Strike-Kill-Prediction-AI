# %% [markdown]
# # Verificação do ambiente (Parte 1)
# Confirma que o PySpark inicia. Depois de gerar `data/csgo_full_dataset.parquet`, descomente a leitura do Parquet.

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("env-check").getOrCreate()
print("Spark:", spark.version)
spark

# %%
# Após o Parquet existir em data/ (montado a partir do repositório local):
# df = spark.read.parquet("/home/jovyan/work/data/csgo_full_dataset.parquet")
# df.printSchema()
# df.count()
